# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("hour.csv")
df1= pd.read_csv("day.csv")

# %%
df.head()
# Out:
#       cow  lactation_number_in_data  TIME  avgtotalmotion  avgtotalsteps  \
# 0  1225.0                       1.0   8.0      299.916667      72.333333
# 1  1225.0                       1.0  10.0      295.750000      72.500000
# 2  1225.0                       1.0  12.0      269.916667      65.750000
# 3  1225.0                       1.0  14.0      265.333333      65.333333
# 4  1225.0                       1.0  16.0      262.083333      64.666667
#
#    avghoursstanding  avghourslying  avglyingbouts  avgrumination  avgactivity  \
# 0          1.518866       0.481134       0.666667            NaN          NaN
# 1          1.554769       0.445231       0.583333            NaN          NaN
# 2          1.554769       0.445231       0.583333            NaN          NaN
# 3          1.554769       0.445231       0.583333            NaN          NaN
# 4          1.583125       0.416875       0.500000            NaN          NaN
#
# ...

# %%
df1.head()
# Out:
#       cow breed  lactation_number_in_data   calvdate       parity  \
# 0  1225.0     H                       1.0  21-Aug-12  multiparous
# 1  1225.0     H                       1.0  21-Aug-12  multiparous
# 2  1225.0     H                       1.0  21-Aug-12  multiparous
# 3  1225.0     H                       1.0  21-Aug-12  multiparous
# 4  1225.0     H                       1.0  21-Aug-12  multiparous
#
#                date  mtotalmotion  mtotalsteps  mhoursstanding  mhourslying  \
# 0  07AUG12:00:00:00    305.833333    77.750000        1.552847     0.426319
# 1  08AUG12:00:00:00    238.750000    61.416667        1.750718     0.249282
# 2  09AUG12:00:00:00    297.583333    77.166667        1.651065     0.348935
# 3  10AUG12:00:00:00    193.666667    50.583333        1.236273     0.763727
# 4  11AUG12:00:00:00    223.666667    56.583333        1.255694     0.744306
#
#    mlyingbouts  mrumination  mactivity  predictedcalving  calved  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1837 entries, 0 to 1836
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cow                       1443 non-null   float64
#  1   lactation_number_in_data  1443 non-null   float64
#  2   TIME                      1443 non-null   float64
#  3   avgtotalmotion            1443 non-null   float64
#  4   avgtotalsteps             1443 non-null   float64
#  5   avghoursstanding          1443 non-null   float64
#  6   avghourslying             1443 non-null   float64
#  7   avglyingbouts             1443 non-null   float64
#  8   avgrumination             1227 non-null   float64
#  9   avgactivity               1227 non-null   float64
#  10  date                      1443 non-null   object
#  11  calvdate                  1443 non-null   object
#  12  Activity                  1227 non-null   float64
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cow                       570 non-null    float64
#  1   breed                     570 non-null    object
#  2   lactation_number_in_data  570 non-null    float64
#  3   calvdate                  570 non-null    object
#  4   parity                    570 non-null    object
#  5   date                      570 non-null    object
#  6   mtotalmotion              570 non-null    float64
#  7   mtotalsteps               570 non-null    float64
#  8   mhoursstanding            570 non-null    float64
#  9   mhourslying               570 non-null    float64
#  10  mlyingbouts               570 non-null    float64
#  11  mrumination               480 non-null    float64
#  12  mactivity                 480 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# cow                         394
# lactation_number_in_data    394
# TIME                        394
# avgtotalmotion              394
# avgtotalsteps               394
# avghoursstanding            394
# avghourslying               394
# avglyingbouts               394
# avgrumination               610
# avgactivity                 610
# date                        394
# calvdate                    394
# Activity                    610
# rumination                  610
# totalmotion                 394
# totalsteps                  394
# hoursstanding               394
# hourslying                  394
# lyingbouts                  394
# predictedcalving            394
# CalvingEaseScore            394
# breed                       394
# calved                      394
# parity                      394
# daysprior                   394
# hoursbefore                 394
# CES                         394
# dayhour                     394
# dtype: int64

# %%
df.dropna()
# Out:
#          cow  lactation_number_in_data  TIME  avgtotalmotion  avgtotalsteps  \
# 36    1246.0                       1.0   8.0      486.750000     136.583333
# 37    1246.0                       1.0  10.0      451.666667     123.750000
# 38    1246.0                       1.0  12.0      412.833333     114.000000
# 39    1246.0                       1.0  14.0      458.000000     126.083333
# 40    1246.0                       1.0  16.0      542.750000     148.583333
# ...      ...                       ...   ...             ...            ...
# 1438  1495.0                       1.0   6.0     2049.083333     546.416667
# 1439  1495.0                       1.0   8.0     2076.000000     553.750000
# 1440  1495.0                       1.0  10.0     2175.083333     574.000000
# 1441  1495.0                       1.0  12.0     2109.166667     557.666667
# 1442  1495.0                       1.0  14.0     2140.833333     553.750000
#
# ...

# %%
df1.isnull().sum()
# Out:
# cow                         147
# breed                       147
# lactation_number_in_data    147
# calvdate                    147
# parity                      147
# date                        147
# mtotalmotion                147
# mtotalsteps                 147
# mhoursstanding              147
# mhourslying                 147
# mlyingbouts                 147
# mrumination                 237
# mactivity                   237
# predictedcalving            147
# calved                      147
# calvingeasescore            147
# date1                       147
# daysprior                   147
# dtype: int64

# %%
df.describe()
# Out:
#                cow  lactation_number_in_data         TIME  avgtotalmotion  \
# count  1443.000000               1443.000000  1443.000000     1443.000000
# mean   1419.929314                  1.136521    11.033957      883.265824
# std      68.690934                  0.343460     6.894556      508.412436
# min    1225.000000                  1.000000     0.000000      195.166667
# 25%    1370.000000                  1.000000     6.000000      569.125000
# 50%    1429.000000                  1.000000    12.000000      779.833333
# 75%    1482.000000                  1.000000    18.000000     1097.500000
# max    1495.000000                  2.000000    22.000000     4213.000000
#
#        avgtotalsteps  avghoursstanding  avghourslying  avglyingbouts  \
# count    1443.000000       1443.000000    1443.000000    1443.000000
# mean      224.211769          1.170277       0.825868       0.939420
# std       123.682800          0.276765       0.277239       0.450790
# ...

# %%
df1.describe()
# Out:
#                cow  lactation_number_in_data  mtotalmotion  mtotalsteps  \
# count   570.000000                570.000000    570.000000   570.000000
# mean   1419.892982                  1.114035    856.770452   211.564752
# std      69.600144                  0.318133    471.633865   110.766948
# min    1225.000000                  1.000000    170.000000    10.250000
# 25%    1367.000000                  1.000000    568.479167   143.500000
# 50%    1429.000000                  1.000000    794.916667   196.625000
# 75%    1482.000000                  1.000000   1058.187500   257.491667
# max    1495.000000                  2.000000   4192.428571   898.857143
#
#        mhoursstanding  mhourslying  mlyingbouts  mrumination   mactivity  \
# count      570.000000   570.000000   570.000000   480.000000  480.000000
# mean         1.069256     0.924675     0.922301    30.009602   29.425551
# std          0.245063     0.247669     0.498782    10.186350   11.696311
# ...

# %%
sns.lmplot(x='hoursbefore', y='avgtotalmotion', data=df)

# %%
sns.lmplot(x='hoursbefore', y='avghourslying', data = df,
scatter_kws={'s': 10, 'alpha': 0.5},line_kws={'lw': 3},x_jitter=True)

# %%
sns.lmplot(x='avgtotalmotion', y='avgtotalsteps', data=df,
scatter_kws={'s': 10, 'alpha': 0.5},
line_kws={'lw': 3},
x_jitter=True)

# %%
sns.barplot(x='hoursbefore', y='avglyingbouts', data=df)
# Out:
# <AxesSubplot:xlabel='hoursbefore', ylabel='avglyingbouts'>

# %%
sns.lmplot(x='hoursbefore', y='avgrumination', data=df,
scatter_kws={'s': 10, 'alpha': 0.5},
line_kws={'lw': 3},
x_jitter=True)

# %%
sns.histplot(x='hoursbefore', y='avgactivity', data=df)
# Out:
# <AxesSubplot:xlabel='hoursbefore', ylabel='avgactivity'>

# %%
# create the plot for mtotalmotion vs. daysprior
sns.lmplot(x="daysprior", y="mtotalmotion", data=df1, x_jitter=True, ci=None, scatter_kws={"s": 20}, line_kws={"lw": 3})

# %%
# create the plot for mtotalsteps vs. daysprior
sns.barplot(x="daysprior", y="mtotalsteps", data=df1)# x_jitter=True, ci=None, scatter_kws={"s": 20}, line_kws={"lw": 3})
# Out:
# <AxesSubplot:xlabel='daysprior', ylabel='mtotalsteps'>

# %%
# create the plot for mhoursstanding vs. daysprior
sns.lmplot(x="daysprior", y="mhoursstanding", data=df1, x_jitter=True, ci=None, scatter_kws={"s": 20}, line_kws={"lw": 3})

# %%
# create the plot for mhourslying vs. daysprior
sns.barplot(x="daysprior", y="mhourslying", data=df1)
# Out:
# <AxesSubplot:xlabel='daysprior', ylabel='mhourslying'>

# %%
# create the plot for mlyingbouts vs. daysprior
sns.lmplot(x="daysprior", y="mlyingbouts", data=df1, x_jitter=True, ci=None, scatter_kws={"s": 20}, line_kws={"lw": 3})

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>
